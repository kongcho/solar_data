# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from f3 import photometry

# %% [markdown]
# Define a target through its KIC identifier. Here, I use KIC 8462852 as an example. ffi_dir is an optional argument
# if your FFIs are stored anywhere other than a subdirectory from your working directory called "ffidata"

# %%
target = photometry.star(8462852)

# %%
target.make_postcard()
# Out:
# WARNING:root:Unrecognized parameter: 'gi_KIS'
# WARNING:root:Unrecognized parameter: 'g_KIS'
# WARNING:root:Unrecognized parameter: 'iz'
# WARNING:root:Unrecognized parameter: 'Metallicity (solar=0.0)'
# WARNING:root:Unrecognized parameter: 'Dec_PM (arcsec/yr)'
# WARNING:root:Unrecognized parameter: 'SCP_ID'
# WARNING:root:Unrecognized parameter: 'Skygroup_ID'
# WARNING:root:Unrecognized parameter: 'KIS RA (J2000)'
# WARNING:root:Unrecognized parameter: 'Kepmag_Source'
# WARNING:root:Unrecognized parameter: 'NUVg_KIS'
# WARNING:root:Unrecognized parameter: 'Sep_UBV_KIS'
# WARNING:root:Unrecognized parameter: 'class_r_KIS'
# WARNING:root:Unrecognized parameter: 'z'
# WARNING:root:Unrecognized parameter: 'Output_2'
# WARNING:root:Unrecognized parameter: 'Teff'
# WARNING:root:Unrecognized parameter: 'JH'
# WARNING:root:Unrecognized parameter: 'HK'
# WARNING:root:Unrecognized parameter: 'class_Ha_KIS'
# WARNING:root:Unrecognized parameter: 'ID_GALEX'
# WARNING:root:Unrecognized parameter: 'err_u_SDSS'
# WARNING:root:Unrecognized parameter: 'Log_G'
# WARNING:root:Unrecognized parameter: 'r_SDSS'
# WARNING:root:Unrecognized parameter: 'dec_USNO'
# WARNING:root:Unrecognized parameter: 'i_SDSS'
# WARNING:root:Unrecognized parameter: 'GALEX FUVNUV'
# WARNING:root:Unrecognized parameter: 'Sep_KIS_IRT'
# WARNING:root:Unrecognized parameter: 'Flux Fraction season 0'
# WARNING:root:Unrecognized parameter: 'gK'
# WARNING:root:Unrecognized parameter: 'Edge_Distance_1 (px)'
# WARNING:root:Unrecognized parameter: 'Seasons on CCD'
# WARNING:root:Unrecognized parameter: 'B_UBV'
# WARNING:root:Unrecognized parameter: 'SDSS Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'A_V'
# WARNING:root:Unrecognized parameter: 'Contamination season 3'
# WARNING:root:Unrecognized parameter: 'SNR season 2'
# WARNING:root:Unrecognized parameter: 'H'
# WARNING:root:Unrecognized parameter: 'J_IRT'
# WARNING:root:Unrecognized parameter: 'dec_IRT'
# WARNING:root:Unrecognized parameter: 'ID_IRT'
# WARNING:root:Unrecognized parameter: '2MASS designation'
# WARNING:root:Unrecognized parameter: 'Crowding season 3'
# WARNING:root:Unrecognized parameter: 'gred'
# WARNING:root:Unrecognized parameter: 'g_SDSS'
# WARNING:root:Unrecognized parameter: 'ra_GALEX'
# WARNING:root:Unrecognized parameter: 'd51mag'
# WARNING:root:Unrecognized parameter: 'Catalog_key'
# WARNING:root:Unrecognized parameter: 'gJ_KIS_IRT'
# WARNING:root:Unrecognized parameter: 'Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'gr_KIS'
# WARNING:root:Unrecognized parameter: 'Photometry_Qual'
# WARNING:root:Unrecognized parameter: 'Total_PM (arcsec/yr)'
# WARNING:root:Unrecognized parameter: 'Sep_UBV_IRT'
# WARNING:root:Unrecognized parameter: 'gJ_KIC_IRT'
# WARNING:root:Unrecognized parameter: 'extinction_r_SDSS'
# WARNING:root:Unrecognized parameter: 'r_KIS'
# WARNING:root:Unrecognized parameter: 'twoMass conflict flag'
# WARNING:root:Unrecognized parameter: 'Var._ID'
# WARNING:root:Unrecognized parameter: 'ID_USNO'
# WARNING:root:Unrecognized parameter: 'RA_hours (J2000)'
# WARNING:root:Unrecognized parameter: 'ra_USNO'
# WARNING:root:Unrecognized parameter: 'V_UBV'
# WARNING:root:Unrecognized parameter: 'ra_IRT'
# WARNING:root:Unrecognized parameter: 'rHa_KIS'
# WARNING:root:Unrecognized parameter: 'z_SDSS'
# WARNING:root:Unrecognized parameter: 'Sep_UBV'
# WARNING:root:Unrecognized parameter: 'KIC Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'kepmag'
# WARNING:root:Unrecognized parameter: 'Contamination season 2'
# WARNING:root:Unrecognized parameter: 'Edge_Distance_3 (px)'
# WARNING:root:Unrecognized parameter: 'Contamination season 0'
# WARNING:root:Unrecognized parameter: 'SNR season 1'
# WARNING:root:Unrecognized parameter: 'ID_SDSS'
# WARNING:root:Unrecognized parameter: 'Table key'
# WARNING:root:Unrecognized parameter: 'Scp_Key'
# WARNING:root:Unrecognized parameter: 'err_g_SDSS'
# WARNING:root:Unrecognized parameter: 'Alt_ID_Source'
# WARNING:root:Unrecognized parameter: 'class_i_KIS'
# WARNING:root:Unrecognized parameter: 'UBV Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'Edge_Distance_0 (px)'
# WARNING:root:Unrecognized parameter: '2MASS RA (J2000)'
# WARNING:root:Unrecognized parameter: 'err_i_SDSS'
# WARNING:root:Unrecognized parameter: 'Condition flag'
# WARNING:root:Unrecognized parameter: 'g'
# WARNING:root:Unrecognized parameter: 'Output_0'
# WARNING:root:Unrecognized parameter: 'E(B-V)'
# WARNING:root:Unrecognized parameter: 'extinction_u_SDSS'
# WARNING:root:Unrecognized parameter: 'r'
# WARNING:root:Unrecognized parameter: 'jClass_IRT'
# WARNING:root:Unrecognized parameter: '2MASS Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'RA (J2000)'
# WARNING:root:Unrecognized parameter: 'Flux Fraction season 3'
# WARNING:root:Unrecognized parameter: 'Flux Fraction season 1'
# WARNING:root:Unrecognized parameter: 'SNR season 3'
# WARNING:root:Unrecognized parameter: 'Gal_Lon (deg)'
# WARNING:root:Unrecognized parameter: 'ug_SDSS'
# WARNING:root:Unrecognized parameter: 'det_UBV'
# WARNING:root:Unrecognized parameter: 'K'
# WARNING:root:Unrecognized parameter: 'extinction_i_SDSS'
# WARNING:root:Unrecognized parameter: 'Sep_KIS'
# WARNING:root:Unrecognized parameter: '2MASS ID'
# WARNING:root:Unrecognized parameter: 'JErr_IRT'
# WARNING:root:Unrecognized parameter: 'Radius (solar=1.0)'
# WARNING:root:Unrecognized parameter: 'Astrophysics_Qual'
# WARNING:root:Unrecognized parameter: 'Gal_Lat (deg)'
# WARNING:root:Unrecognized parameter: 'i_KIS'
# WARNING:root:Unrecognized parameter: 'pStar_IRT'
# WARNING:root:Unrecognized parameter: 'Alt_ID'
# WARNING:root:Unrecognized parameter: 'Crowding season 2'
# WARNING:root:Unrecognized parameter: 'U_KIS'
# WARNING:root:Unrecognized parameter: 'ID_KIS'
# WARNING:root:Unrecognized parameter: 'Ha_KIS'
# WARNING:root:Unrecognized parameter: 'err_r_SDSS'
# WARNING:root:Unrecognized parameter: 'err_z_SDSS'
# WARNING:root:Unrecognized parameter: 'gr_SDSS'
# WARNING:root:Unrecognized parameter: 'dec_GALEX'
# WARNING:root:Unrecognized parameter: 'SNR season 0'
# WARNING:root:Unrecognized parameter: 'gi_SDSS'
# WARNING:root:Unrecognized parameter: 'KIC RA (J2000)'
# WARNING:root:Unrecognized parameter: 'ID_UBV'
# WARNING:root:Unrecognized parameter: 'Edge_Distance_2 (px)'
# WARNING:root:Unrecognized parameter: 'Output_3'
# WARNING:root:Unrecognized parameter: 'KIS Dec (J2000)'
# WARNING:root:Unrecognized parameter: 'UB_UBV'
# WARNING:root:Unrecognized parameter: 'GALEX FUV'
# WARNING:root:Unrecognized parameter: 'Contamination season 1'
# WARNING:root:Unrecognized parameter: 'Ug_KIS'
# WARNING:root:Unrecognized parameter: 'extinction_z_SDSS'
# WARNING:root:Unrecognized parameter: 'jppErrBits_IRT'
# WARNING:root:Unrecognized parameter: 'BV_UBV'
# WARNING:root:Unrecognized parameter: 'Data Availability'
# WARNING:root:Unrecognized parameter: 'i'
# WARNING:root:Unrecognized parameter: 'KIS_ID_KIS'
# WARNING:root:Unrecognized parameter: 'u_SDSS'
# WARNING:root:Unrecognized parameter: 'extinction_g_SDSS'
# WARNING:root:Unrecognized parameter: 'class_g_KIS'
# WARNING:root:Unrecognized parameter: 'JK'
# WARNING:root:Unrecognized parameter: 'UBV RA (J2000)'
# WARNING:root:Unrecognized parameter: 'RA_PM (arcsec/yr)'
# WARNING:root:Unrecognized parameter: 'gi'
# WARNING:root:Unrecognized parameter: 'NUVg'
# WARNING:root:Unrecognized parameter: 'Flux Fraction season 2'
# WARNING:root:Unrecognized parameter: 'Crowding season 0'
# WARNING:root:Unrecognized parameter: 'class_U_KIS'
# WARNING:root:Unrecognized parameter: 'GALEX NUV'
# WARNING:root:Unrecognized parameter: 'Sep_IRT'
# WARNING:root:Unrecognized parameter: 'Master ID'
# WARNING:root:Unrecognized parameter: 'J'
# WARNING:root:Unrecognized parameter: 'SDSS RA (J2000)'
# WARNING:root:Unrecognized parameter: 'Crowding season 1'
# WARNING:root:Unrecognized parameter: 'Star/Gal_ID'
# WARNING:root:Unrecognized parameter: 'Output_1'
# WARNING:root:Unrecognized parameter: 'gJ'

# %% [markdown]
# The step above takes all the FFIs and locates a small region centered on the target. It takes three optional arguments. npix is the size of the square postcard region. shape=(1070,1132) is the size of the FFIs, which can be changed if you're adapting the code to something other than Kepler FFIs (such as TESS data). buffer_size avoids the outermost pixels on the detector, so that each target should have its entire PSF on the detector.

# %%
target.find_other_sources(plot_flag=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b0214ce7df15> in <module>()
# ----> 1 target.find_other_sources(plot_flag=True)
#
# ~/Desktop/astrolab/solar_data/f3_edit/f3/photometry.py in find_other_sources(self, edge_lim, min_val, ntargets, extend_region_size, remove_excess, plot_flag, plot_window)
#     288
#     289             plt.imshow(((targets == 1)*self.integrated_postcard + (targets == 1)*100000)
# --> 290                        [jj-plot_window:jj+plot_window,ii-plot_window:ii+plot_window],
#     291                        interpolation='nearest', cmap='gray', vmax=np.percentile(self.integrated_postcard, 99.6))
#     292             plt.show()
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# This step will draw apertures around the target star and up to ntargets additional targets on the same postcard.
# It will then remove apertures that touch the border of the postcard and combine apertures that touch into one target,
# treating those stars as a single object for the rest of the procedure.
#
# The "plot_flag" argument will show a stacked plot of the postcard images, then a plot of all apertures for all targets, then a plot of the default aperture for the primary target, and finally data for the entire postcard, with apertures for all targets highlighted over the data.

# %%
target.adjust_aperture(ignore_bright=0)

# %% [markdown]
# Perhaps the initial aperture isn't appropriate, because it contians another star or doesn't capture the entire PSF, for example. This routine will enable you to change the aperture for the target star. It will open up a window showing the aperture (and underlying data) and the current light curve for the target star. By clicking on individual pixels, you can include or exclude them from the aperture. Closing the panel will then cause the photometry pipeline to re-run, and you can see how the light curve has changed from including/excluding those pixels. This will repeat until the image is closed without any changes to the aperture.
#
# Clicking on the zeroth row/column (on the top or left) will cause all pixels in that column/row (respectively) to be turned off.
#
# Re-running find_other_sources will restart this procedure, giving you back the default aperture. (Note: this routine won't work in a Jupyter notebook, but will from the command line or in a script.)

# %%
fmt = ['ko', 'rD', 'b^', 'gs']

for i in xrange(4):
    g = np.where(target.qs == i)[0]
    plt.errorbar(target.times[g], target.obs_flux[g], yerr=target.flux_uncert[i], fmt=fmt[i])

# %% [markdown]
# The error bars are overestimated in this case---they represent the residuals to a linear fit to the data, which is clearly inappropriate for this star. The colors/shapes represent different orientations of the spacecraft as it rotates to keep its solar panels aligned with the Sun.

# %%
target.data_for_target(ignore_bright=0)

# %% [markdown]
# This calculates photometry without the aperture varying step, just using whatever aperture is currently defined (where target.targets == 1). target.targets == 0 is the background, and all other integers correspond to different targets.

# %%
target.calc_centroids()

# %% [markdown]
# Measures the centroid shift.

# %%
for i in xrange(4):
    g = np.where(target.qs == i)[0]
    plt.errorbar(target.cm[g,0], target.obs_flux[g], yerr=target.flux_uncert[i], fmt=fmt[i])
    
plt.show()
    
for i in xrange(4):
    g = np.where(target.qs == i)[0]
    plt.errorbar(target.cm[g,1], target.obs_flux[g], yerr=target.flux_uncert[i], fmt=fmt[i])

# %% [markdown]
# No obvious correlation with the large dimming here!

# %%
target.define_spotsignal()

# %% [markdown]
# This roughly estimates with the flux "should" be at the FFI times based on the starspot signal at the last observation before the FFIs by computing the flux at that last observation (1 hour before the FFI) relative to the median flux in that quarter of observations. Useful for making sure you're not being confused with aliasing.

# %% [markdown]
# We then can use the method in the appendix of our paper to model the uncertainties.

# %%
target.model_uncert()

# %%
for i in xrange(4):
    g = np.where(target.qs == i)[0]
    plt.errorbar(target.times[g], target.obs_flux[g], yerr=target.target_uncert[g], fmt=fmt[i])
plt.xlabel('Time')
plt.ylabel('Normalized Flux')

# %% [markdown]
# Looks reasonable!
